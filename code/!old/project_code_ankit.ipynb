# %% [markdown]
# # Econ 695 Project
# Due: 12/17/2025. Submit this notebook or other scripts you use to produce the tables and figures along with your report.
#
# Read "ECON695_project.pdf" for details on each expected output.

# %%
import pandas as pd 
import os  # for setting directory 
# os.chdir() # input your personal directory where the dataset is saved
import statsmodels.formula.api as smf # for OLS regressions
import numpy as np  # to work with arrays (vectors/matrices)
import matplotlib.pyplot as plt # for plots

# %%
import os
csv_path = '../projectdata.csv'
print("File exists:", os.path.exists(csv_path))

data = pd.read_csv(csv_path)
print(data.shape)
data.head(2)
# Out:
# File exists: True
# (16969, 12)
#           y  age  educ  female  exp       yl1       yl2       yl3       yp1  \
# 0  2.570021   48    12       0   30  2.620926  2.616735  2.608906  2.784972
# 1  2.298948   46    12       1   28  2.296236  2.284491  2.275459  2.309241
#
#         yp2    owage2    owage1
# 0  2.791555  1.191211  1.122809
# 1  2.320770  2.397997  2.485690

# %%
print(data['female'].value_counts(dropna=False))
print(data['educ'].value_counts(dropna=False))
data.describe()
# Out:
# female
# 0    10575
# 1     6394
# Name: count, dtype: int64
# educ
# 12    5019
# 6     4651
# 9     3859
# 16    3440
# Name: count, dtype: int64
#                   y           age          educ        female           exp  \
# count  16969.000000  16969.000000  16969.000000  16969.000000  16969.000000
# mean       1.787921     33.558902     10.484118      0.376805     17.074783
# std        0.645257      5.693736      3.586129      0.484600      6.446165
# min        0.601944     22.000000      6.000000      0.000000      5.000000
# 25%        1.297586     29.000000      6.000000      0.000000     12.000000
# 50%        1.617799     33.000000      9.000000      0.000000     17.000000
# 75%        2.194695     37.000000     12.000000      1.000000     22.000000
# max        4.343445     52.000000     16.000000      1.000000     30.000000
#
#                 yl1           yl2           yl3           yp1           yp2  \
# count  16969.000000  16969.000000  16969.000000  16969.000000  16969.000000
# mean       1.736934      1.717822      1.696991      1.806854      1.840162
# std        0.610285      0.600409      0.590419      0.646991      0.650853
# min        0.603566      0.592804      0.590613      0.637028      0.696327
# 25%        1.276873      1.264874      1.249482      1.315681      1.346496
# 50%        1.576101      1.566374      1.551751      1.635421      1.660561
# 75%        2.120593      2.095272      2.058599      2.216467      2.252076
# max        4.237082      4.300920      4.315834      4.322492      4.399618
#
#              owage2        owage1
# count  16969.000000  16969.000000
# mean       1.692074      1.648420
# std        0.466264      0.472052
# min        0.716435      0.718321
# 25%        1.352856      1.299025
# 50%        1.561470      1.550452
# 75%        1.957534      1.889397
# max        3.804267      3.808492

# %% [markdown]
# # Section 1. Overview: Female vs. Male Workers
# ## Summary Statistics (Table 1)
# A suggested format for **Table 1** is to have 4 columns:
# - column 1 = characteristics for all workers
# - column 2 = characteristics for female workers
# - column 3 = characteristics for male workers
# - column 4 = test statistic comparing females and males (eg t-test)
#
# See the project.pdf for the list of characteristics.
# Hint: to convert a dataframe to LaTex table, use `table.to_latex(float_format="%.3f")`. You could also copy-paste the estimates into excel and format it manually.

# %%
import pandas as pd
import numpy as np
from scipy import stats

import os
csv_path = '../projectdata.csv'
print("File exists:", os.path.exists(csv_path))

df = pd.read_csv(csv_path)

# Education category shares
df['educ_6']  = (df['educ'] == 6).astype(int)
df['educ_9']  = (df['educ'] == 9).astype(int)
df['educ_12'] = (df['educ'] == 12).astype(int)
df['educ_16'] = (df['educ'] == 16).astype(int)

# Variables required in Table 1
continuous_vars = ["age", "y", "owage2"]
edu_vars = ["educ_6", "educ_9", "educ_12", "educ_16"]
all_vars = continuous_vars + edu_vars

# --- Compute summary stats ---
table1 = pd.DataFrame(index=all_vars)

table1["All"]    = df[all_vars].mean()
table1["Female"] = df[df.female == 1][all_vars].mean()
table1["Male"]   = df[df.female == 0][all_vars].mean()

# --- t-stats for ALL variables (continuous + dummies) ---
t_stats = {
    v: stats.ttest_ind(
            df.loc[df.female == 1, v],
            df.loc[df.female == 0, v],
            equal_var=False,
            nan_policy='omit'
        )[0]
    for v in all_vars
}

table1["t_stat"] = table1.index.map(lambda x: t_stats.get(x, np.nan))

# Rename rows for report-readability
table1.index = [
    "Age (mean)",
    "Log Wage y (mean)",
    "Coworker Wage owage2 (mean)",
    "Educ = 6 yrs (fraction)",
    "Educ = 9 yrs (fraction)",
    "Educ = 12 yrs (fraction)",
    "Educ = 16 yrs (fraction)"
]

table1
# Out:
# File exists: True
#                                    All     Female       Male     t_stat
# Age (mean)                   33.558902  33.534407  33.573712  -0.435839
# Log Wage y (mean)             1.787921   1.658045   1.866448 -20.816260
# Coworker Wage owage2 (mean)   1.692074   1.637794   1.724893 -11.676093
# Educ = 6 yrs (fraction)       0.274088   0.248671   0.289456  -5.845916
# Educ = 9 yrs (fraction)       0.227415   0.194870   0.247092  -8.045046
# Educ = 12 yrs (fraction)      0.295775   0.328589   0.275934   7.205363
# Educ = 16 yrs (fraction)      0.202723   0.227870   0.187518   6.231668

# %% [markdown]
# ## Distribution of Wages (Figure 1)
# - Figure 1: histogram of log hourly wages for men and women in one figure.
# - Bonus (Figure 1b): Develop some interesting ways to illustrate the fact that women's wages are lower than men's.

# %%
from scipy.stats import gaussian_kde
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------------
# Path to figures folder
# -----------------------------
FIG_DIR = "/Users/alexdelatorre/Library/CloudStorage/OneDrive-UW-Madison/Coursework/ECON 695/final_project_econ695/report/figures"
os.makedirs(FIG_DIR, exist_ok=True)

female_w = df.loc[df.female == 1, "yp1"]
male_w   = df.loc[df.female == 0, "yp1"]

# -----------------------------
# Figure 1a — KDE Density Plot
# -----------------------------
x_grid = np.linspace(df["yp1"].min(), df["yp1"].max(), 300)

plt.figure(figsize=(10, 6))
plt.plot(x_grid, gaussian_kde(female_w)(x_grid), color="red",  label="Female", linewidth=2)
plt.plot(x_grid, gaussian_kde(male_w)(x_grid),   color="blue", label="Male",   linewidth=2)

plt.title("Figure 1a: KDE Distribution of Log Hourly Wages (yp1)")
plt.xlabel("Log Wage (yp1)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()

# Save + show
fig1a_path = os.path.join(FIG_DIR, "fig1a_kde_wages_ankit.png")
plt.savefig(fig1a_path, dpi=300)
plt.show()

# -----------------------------
# Figure 1b — Histogram
# -----------------------------
num_bins = 25  # fewer bins so density < 1
bins = np.linspace(df["yp1"].min(), df["yp1"].max(), num_bins)

plt.figure(figsize=(10, 6))
plt.hist(female_w, bins=bins, density=True, alpha=0.5,
         color="red",  label="Female", edgecolor="black")
plt.hist(male_w,   bins=bins, density=True, alpha=0.5,
         color="blue", label="Male",   edgecolor="black")

plt.title("Figure 1b: Histogram of Log Hourly Wages (yp1)")
plt.xlabel("Log Wage (yp1)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()

# Save + show
fig1b_path = os.path.join(FIG_DIR, "fig1b_hist_wages_ankit.png")
plt.savefig(fig1b_path, dpi=300)
plt.show()

# %% [markdown]
# # Section 2. Gender Wage Gaps
# ## 2.1 Wage Regressions and Oaxaca Decomposition (Table 2)
# In Table 2, you will fit a series of standard wage models. The first set of columns are estimated using the pooled data for women and men. The second set are estimated separately by gender, based on which you can conduct an Oaxaca decomposition.

# %%
# sample code for generating a LaTex Table for regressions 
'''
from statsmodels.iolib.summary2 import summary_col
summary = summary_col(
    results=[model0, model1],
    float_format='%0.3f', stars=False,
    model_names=['(1)', '(2)'],
    info_dict={
        'N': lambda x: f"{int(x.nobs)}", 'Adj R2': lambda x: f"{x.rsquared_adj:.3f}"
    }
)
summary.as_latex()

'''
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col
import matplotlib.pyplot as plt

df = data.copy()

# Experience polynomial terms
df["exp2"] = df["exp"]**2
df["exp3"] = df["exp"]**3

# Model 0: y ~ female
model0 = smf.ols("y ~ female", data=df).fit()

# Model 1: y ~ female + education + experience cubic
model1 = smf.ols("y ~ female + C(educ) + exp + exp2 + exp3", data=df).fit()

# Display LaTeX-style combined table
table2_pooled = summary_col(
    results=[model0, model1],
    float_format='%0.3f',
    stars=False,
    model_names=['(1)', '(2)'],
    info_dict={
        'N': lambda x: f"{int(x.nobs)}",
        'Adj R2': lambda x: f"{x.rsquared_adj:.3f}"
    }
)

table2_pooled

male = df[df.female == 0]
female_df = df[df.female == 1]

model_m = smf.ols("y ~ C(educ) + exp + exp2 + exp3", data=male).fit()
model_f = smf.ols("y ~ C(educ) + exp + exp2 + exp3", data=female_df).fit()

table2_gender = summary_col(
    results=[model_m, model_f],
    float_format='%0.3f',
    stars=False,
    model_names=['Male', 'Female'],
    info_dict={
        'N': lambda x: f"{int(x.nobs)}",
        'Adj R2': lambda x: f"{x.rsquared_adj:.3f}"
    }
)

table2_gender

import patsy

# Build design matrices exactly as in model_m and model_f
formula = "y ~ C(educ) + exp + exp2 + exp3"

y_m, X_m = patsy.dmatrices(formula, male, return_type='dataframe')
y_f, X_f = patsy.dmatrices(formula, female_df, return_type='dataframe')

# Drop intercept for decomposition
X_m_noi = X_m.drop(columns="Intercept")
X_f_noi = X_f.drop(columns="Intercept")

# Compute means of covariates
Xm = X_m_noi.mean()
Xf = X_f_noi.mean()

# Extract coefficients (drop intercept)
bm = model_m.params.drop("Intercept")
bf = model_f.params.drop("Intercept")

# Align indices
bm = bm.reindex(Xm.index)
bf = bf.reindex(Xm.index)

# Oaxaca components
explained = float((Xm - Xf) @ bf)
unexplained = float(Xm @ (bm - bf))
total_gap = explained + unexplained

# Output table
oaxaca_results = pd.DataFrame({
    "Explained": [explained],
    "Unexplained": [unexplained],
    "Total Gap": [total_gap]
})

oaxaca_results
# Out:
#    Explained  Unexplained  Total Gap
# 0  -0.062301     0.107111    0.04481

# %% [markdown]
# ## 2.2 Gender Difference in Experience Profiles
# - Figure 2: Plot the relationship between wages and experience for men and women who have one level of education (e.g., education=12), and show the fit of your regression models.
# - Bonus (Figure 2 continued): Consider plotting “Figure 2” for each of the 4 education groups. Within each education group, how much of the gender gap can be explained by differences in experience profile?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import os

# -------------------------------------------------------------------
# Path to figures folder (same as before)
# -------------------------------------------------------------------
FIG_DIR = "/Users/alexdelatorre/Library/CloudStorage/OneDrive-UW-Madison/Coursework/ECON 695/final_project_econ695/report/figures"
os.makedirs(FIG_DIR, exist_ok=True)

# -------------------------------------------------------------------
# Make sure exp2 and exp3 exist
# -------------------------------------------------------------------
if "exp2" not in df.columns:
    df["exp2"] = df["exp"]**2
if "exp3" not in df.columns:
    df["exp3"] = df["exp"]**3

# ================================
# Figure 2: edu_group = 12
# ================================

# Choose education group
edu_group = 12
sub = df[df.educ == edu_group]

# Fit by gender
fit_m = smf.ols("y ~ exp + exp2 + exp3", data=sub[sub.female == 0]).fit()
fit_f = smf.ols("y ~ exp + exp2 + exp3", data=sub[sub.female == 1]).fit()

# Range of experience for plotting
xp = np.linspace(sub.exp.min(), sub.exp.max(), 200)
Xp = pd.DataFrame({"exp": xp, "exp2": xp**2, "exp3": xp**3})

# Plot raw data + fitted curves
plt.figure(figsize=(9, 6))
plt.scatter(sub[sub.female == 0].exp, sub[sub.female == 0].y,
            alpha=0.3, label="Men")
plt.scatter(sub[sub.female == 1].exp, sub[sub.female == 1].y,
            alpha=0.3, label="Women")

plt.plot(xp, fit_m.predict(Xp), linewidth=3, label="Male Fit")
plt.plot(xp, fit_f.predict(Xp), linewidth=3, label="Female Fit")

plt.title(f"Figure 2: Wage–Experience Profile (Education = {edu_group})")
plt.xlabel("Experience")
plt.ylabel("Log Wage (y)")
plt.legend()
plt.tight_layout()

# Save + show
fig2_path = os.path.join(FIG_DIR, f"fig2_exp_profile_edu{edu_group}_ankit.png")
plt.savefig(fig2_path, dpi=300)
plt.show()

# ================================
# Figure 2 Bonus: edu = 6, 9, 12, 16
# ================================

for e in [6, 9, 12, 16]:
    sub = df[df.educ == e]
    if len(sub) < 50:
        continue

    fit_m = smf.ols("y ~ exp + exp2 + exp3", data=sub[sub.female == 0]).fit()
    fit_f = smf.ols("y ~ exp + exp2 + exp3", data=sub[sub.female == 1]).fit()

    xp = np.linspace(sub.exp.min(), sub.exp.max(), 200)
    Xp = pd.DataFrame({"exp": xp, "exp2": xp**2, "exp3": xp**3})

    plt.figure(figsize=(9, 6))
    plt.plot(xp, fit_m.predict(Xp), linewidth=3, label="Male Fit")
    plt.plot(xp, fit_f.predict(Xp), linewidth=3, label="Female Fit")

    plt.title(f"Figure 2 (Bonus): Wage–Experience Profile (Education = {e})")
    plt.xlabel("Experience")
    plt.ylabel("Log Wage (y)")
    plt.legend()
    plt.tight_layout()

    # Save + show
    bonus_path = os.path.join(FIG_DIR, f"fig2_bonus_exp_profile_edu{e}_ankit.png")
    plt.savefig(bonus_path, dpi=300)
    plt.show()

# %% [markdown]
# # Section 3. Gender Wage Gaps Conditional on Coworker Wages
#
# **Table 3** will report 5 models.
#
# The first set of models are estimated in the pooled data for men and women:
# - including only a constant, a female dummy, and owage2
# - including a constant, education, a cubic in experience, a female dummy, and owage2
# - including a constant, education, a cubic in experience, a female dummy, owage2, and the interaction of owage2 with the female dummy.
#
# Then, fit separate models for men and women that include a constant, education, and a cubic in experience and owage2. Use these models to perform a new decomposition that accounts for the effect of higher-wage coworkers.

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col
import patsy

df = data.copy()

# Add experience polynomial terms
df["exp2"] = df["exp"]**2
df["exp3"] = df["exp"]**3

# ---------------------------------------------------------
#  PART 1 — 3 POOLED MODELS  (Full sample men+women)
# ---------------------------------------------------------

# Model 1: Constant + female dummy + owage2
model1 = smf.ols("y ~ female + owage2", data=df).fit()

# Model 2: + education + cubic experience
model2 = smf.ols("y ~ female + owage2 + C(educ) + exp + exp2 + exp3", data=df).fit()

# Model 3: + interaction female × owage2
model3 = smf.ols("y ~ female * owage2 + C(educ) + exp + exp2 + exp3", data=df).fit()

# Combine pooled models into a LaTeX-ready table
table3_pooled = summary_col(
    results=[model1, model2, model3],
    float_format='%0.3f',
    stars=False,
    model_names=['(1)', '(2)', '(3)'],
    info_dict={
        'N': lambda x: f"{int(x.nobs)}",
        'Adj R2': lambda x: f"{x.rsquared_adj:.3f}"
    }
)

display(table3_pooled)

# ---------------------------------------------------------
#  PART 2 — 2 GENDER–SPECIFIC MODELS
# ---------------------------------------------------------

male = df[df.female == 0]
female_df = df[df.female == 1]

model_male = smf.ols("y ~ C(educ) + exp + exp2 + exp3 + owage2", data=male).fit()
model_female = smf.ols("y ~ C(educ) + exp + exp2 + exp3 + owage2", data=female_df).fit()

table3_gender = summary_col(
    results=[model_male, model_female],
    float_format='%0.3f',
    stars=False,
    model_names=['Male', 'Female'],
    info_dict={
        'N': lambda x: f"{int(x.nobs)}",
        'Adj R2': lambda x: f"{x.rsquared_adj:.3f}"
    }
)

display(table3_gender)

# ---------------------------------------------------------
#  PART 3 — NEW OAXACA-STYLE DECOMPOSITION (including coworker wages)
# ---------------------------------------------------------

# Build exact design matrices as used in the regressions
formula = "y ~ C(educ) + exp + exp2 + exp3 + owage2"

y_m, X_m = patsy.dmatrices(formula, male,      return_type='dataframe')
y_f, X_f = patsy.dmatrices(formula, female_df, return_type='dataframe')

# Drop intercept for decomposition
X_m_noi = X_m.drop(columns="Intercept")
X_f_noi = X_f.drop(columns="Intercept")

# Group means of predictors
Xm = X_m_noi.mean()
Xf = X_f_noi.mean()

# Extract and align coefficients
bm = model_male.params.drop("Intercept").reindex(Xm.index)
bf = model_female.params.drop("Intercept").reindex(Xm.index)

# Oaxaca components
explained = float((Xm - Xf) @ bf)
unexplained = float(Xm @ (bm - bf))
total_gap = explained + unexplained

decomp_table = pd.DataFrame({
    "Explained (incl. coworker wages)": [explained],
    "Unexplained": [unexplained],
    "Total Gap": [total_gap]
})

display(decomp_table)
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#
# ======================================
#                  (1)     (2)     (3)
# --------------------------------------
# Intercept      0.131   -0.199  -0.244
#                (0.013) (0.047) (0.047)
# female         -0.121  -0.189  -0.071
#                (0.007) (0.005) (0.020)
# owage2         1.006   0.634   0.662
#                (0.007) (0.007) (0.008)
# C(educ)[T.9]           0.153   0.154
#                        (0.008) (0.008)
# C(educ)[T.12]          0.377   0.377
#                        (0.008) (0.008)
# C(educ)[T.16]          1.011   1.013
#                        (0.010) (0.010)
# exp                    0.056   0.055
#                        (0.009) (0.009)
# exp2                   -0.001  -0.001
#                        (0.001) (0.001)
# exp3                   -0.000  -0.000
#                        (0.000) (0.000)
# female:owage2                  -0.070
#                                (0.011)
# R-squared      0.549   0.727   0.727
# R-squared Adj. 0.548   0.727   0.727
# Adj R2         0.548   0.727   0.727
# N              16969   16969   16969
# ======================================
# Standard errors in parentheses.
# """
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#
# ==============================
#                  Male   Female
# ------------------------------
# Intercept      -0.297  -0.284
#                (0.064) (0.066)
# C(educ)[T.9]   0.150   0.165
#                (0.010) (0.013)
# C(educ)[T.12]  0.394   0.349
#                (0.011) (0.013)
# C(educ)[T.16]  1.030   0.978
#                (0.013) (0.016)
# exp            0.056   0.062
#                (0.012) (0.013)
# exp2           -0.001  -0.002
#                (0.001) (0.001)
# exp3           -0.000  0.000
#                (0.000) (0.000)
# owage2         0.660   0.598
#                (0.009) (0.010)
# R-squared      0.707   0.748
# R-squared Adj. 0.707   0.748
# Adj R2         0.707   0.748
# N              10575   6394
# ==============================
# Standard errors in
# parentheses.
# """
#    Explained (incl. coworker wages)  Unexplained  Total Gap
# 0                          0.016811     0.204303   0.221114

# %% [markdown]
# # Section 4. Event Study - Wage Changes around Moves
#
# - **Figure 3**: Conduct 9 separate event studies, plotting mean wages in period -3, -2, -1, 0, 1, 2 for people who start in each tercile of `owage1` and go to each tercile of `owage2`.
#
# - **Table 4**: Model the change in wages from -1 to 0 (y - yl1) as a function of the change in the mean log wage of co-workers (owage2 - owage1).
#
# - **Bonus (Table 4b)**: Apply shrinkage methods to first-differenced models that control for interactions between (owage2 - owage1) and experience dummies.

# %% [markdown]
# ## Figure 3
# Hint: get the terciles of owage1, owage2 via `qcut`.
# Reshape the data to a panel data at (person, l) level where $l=-3,-2,-1,0,1,2$ -- years relative to the move to the 2nd job. There are multiple ways to reshape the data from wide to long. For example, you can set the index of a dataframe first and then `stack`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------------------------------------------
# Path to figures folder
# -----------------------------------------------------------
FIG_DIR = "/Users/alexdelatorre/Library/CloudStorage/OneDrive-UW-Madison/Coursework/ECON 695/final_project_econ695/report/figures"
os.makedirs(FIG_DIR, exist_ok=True)

# -----------------------------------------------------------
# Build panel data with coworker-wage terciles
# -----------------------------------------------------------
df = data.copy()   # or assume 'data' already loaded earlier

# Create terciles for owage1 and owage2
df["ow1_terc"] = pd.qcut(df["owage1"], 3, labels=[1, 2, 3])
df["ow2_terc"] = pd.qcut(df["owage2"], 3, labels=[1, 2, 3])

# Reshape wages wide → long
wide = df[["y", "yl1", "yl2", "yl3", "yp1", "yp2"]].copy()
wide.columns = ["0", "-1", "-2", "-3", "+1", "+2"]

wide_long = wide.stack().reset_index()
wide_long.columns = ["id", "event_time", "wage"]

# Merge back tercile info
panel = pd.merge(
    wide_long,
    df[["ow1_terc", "ow2_terc"]],
    left_on="id",
    right_index=True
)

# Convert event_time to int (-3, -2, -1, 0, 1, 2)
panel["event_time"] = panel["event_time"].astype(int)

# -----------------------------------------------------------
# Figure 3: 3 panels (start terciles), 3 lines each (end terciles)
# -----------------------------------------------------------
event_grid = [-3, -2, -1, 0, 1, 2]

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

for i, start_t in enumerate([1, 2, 3]):
    ax = axes[i]

    for end_t in [1, 2, 3]:
        temp = panel[(panel["ow1_terc"] == start_t) & (panel["ow2_terc"] == end_t)]
        mean_wage = (
            temp.groupby("event_time")["wage"]
                .mean()
                .reindex(event_grid)
        )

        ax.plot(event_grid, mean_wage, marker="o", label=f"End T{end_t}")

    ax.axvline(0, color="black", linestyle="--", linewidth=1)
    ax.set_title(f"Start T{start_t}")
    ax.set_xlabel("Event Time (years)")
    if i == 0:
        ax.set_ylabel("Mean Log Wage")

    ax.set_xticks(event_grid)

fig.suptitle(
    "Figure 3: Event Study of Wage Paths by Coworker Wage Tercile Transitions",
    fontsize=16
)
fig.tight_layout(rect=[0, 0.02, 1, 0.92])

# Save + show
fig3_path = os.path.join(FIG_DIR, "fig3_event_study_ankit.png")
plt.savefig(fig3_path, dpi=300)
plt.show()

# %% [markdown]
# ## Table 4:

# %%
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

# Recreate exp2 and exp3 to avoid NameError
df["exp2"] = df["exp"]**2
df["exp3"] = df["exp"]**3

# Wage change
df["dy"] = df["y"] - df["yl1"]

# Coworker wage change
df["d_ow"] = df["owage2"] - df["owage1"]

# Base model
m1 = smf.ols("dy ~ d_ow", data=df).fit()

# Model with controls
m2 = smf.ols("dy ~ d_ow + C(educ) + exp + exp2 + exp3 + female", data=df).fit()

# Output table
table4 = summary_col(
    results=[m1, m2],
    float_format='%0.3f',
    stars=False,
    model_names=['(1)','(2)'],
    info_dict={
        'N': lambda x: f"{int(x.nobs)}",
        'Adj R2': lambda x: f"{x.rsquared_adj:.3f}"
    }
)

display(table4)
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#
# ==============================
#                  (1)     (2)
# ------------------------------
# Intercept      0.038   0.116
#                (0.002) (0.035)
# d_ow           0.293   0.296
#                (0.006) (0.006)
# C(educ)[T.9]           0.004
#                        (0.006)
# C(educ)[T.12]          0.030
#                        (0.006)
# C(educ)[T.16]          0.081
#                        (0.007)
# exp                    -0.013
#                        (0.007)
# exp2                   0.001
#                        (0.000)
# exp3                   -0.000
#                        (0.000)
# female                 -0.025
#                        (0.004)
# R-squared      0.108   0.130
# R-squared Adj. 0.108   0.129
# Adj R2         0.108   0.129
# N              16969   16969
# ==============================
# Standard errors in
# parentheses.
# """

# %% [markdown]
# ## Bonus: Shrinkage

# %%
# For Ridge/Lasso: 
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV

# Suppose you have defined a dataframe/matrix X with regressors, and y = change in log wage. Try the following: 
'''
fd_Ridge =RidgeCV(fit_intercept=True,cv=5).fit(X, y) 
# extract coefficients: 
[fd_Ridge.intercept_.item()] + fd_Ridge.coef_.tolist()
# For Lasso: 
fd_Lasso =LassoCV(cv=5).fit(X, y)
[fd_Lasso.intercept_.item()] + fd_Lasso.coef_.tolist()
'''
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import RidgeCV, LassoCV

# Construct design matrix
X = df[["d_ow","exp","exp2","exp3"]].copy()

# Add education dummies
edu_dum = pd.get_dummies(df["educ"], prefix="edu", drop_first=True)
X = pd.concat([X, edu_dum], axis=1)

y = df["dy"]

# Ridge Regression with CV
ridge = RidgeCV(cv=5, fit_intercept=True).fit(X, y)
ridge_coefs = [ridge.intercept_] + ridge.coef_.tolist()

# Lasso Regression with CV
lasso = LassoCV(cv=5, fit_intercept=True).fit(X, y)
lasso_coefs = [lasso.intercept_] + lasso.coef_.tolist()

print("Ridge coefficients:", ridge_coefs)
print("Lasso coefficients:", lasso_coefs)
# Out:
# Ridge coefficients: [0.09916378959470296, 0.2931536640953848, -0.011027497814760137, 0.00048786212086986537, -8.42469613447413e-06, 0.004151043562471337, 0.02827561944846721, 0.07838611638564723]
# Lasso coefficients: [0.10641043194338012, 0.0, -0.0, -0.00028160128419413326, 5.354040180172019e-06, -0.0, 0.0, 0.0]
